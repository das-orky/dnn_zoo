# %% [markdown]
# ##### Side note: self.training is an internal parameter, describing whether the model is in training mode or not. Used in GoogleLeNet (or Inception)

# %%
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
import einops

# %%
class ImageTransformer(nn.Module):
    def __init__(self,*,image_size,patch_size,num_classes,dim,depth,heads, mlp_dim, channels=3,
                dropout=0.1, emb_dropout=0.1):
        super(ImageTransformer,self).__init__()
        
        assert image_size % patch_size == 0
        num_patches=(image_size//patch_size)**2
        self.patch_size=patch_size
        
        self.pos_embedding=nn.Parameter(torch.empty(1,(num_patches+1),dim))
        nn.init.normal_(self.pos_embedding,std=0.02)
        # Patches are created by using a conv2d layer, you can write another function to do it also
        self.patch_conv = nn.Conv2d(3,dim,patch_size,stride=patch_size)
        # for each dim there is one learning parameter
        self.cls_token=nn.Parameter(torch.zeros(1,1,dim))
        self.dropout=nn.Dropout(emb_dropout)
        
        self.transformer=Transformer(dim,depth,heads,mlp_dim,dropout) # depth number of transformer blocks
        self.to_cls_token=nn.Identity()
        self.fc1=nn.Linear(dim,num_classes)
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.normal_(self.fc1.bias, std=1e-6)
        
    def forward(self,img,mask=None):
        x=self.patch_conv(img)
        x=einops.rearrange(x,'b c h w -> b (h w) c')
        cls_tokens=self.cls_token.expand(img.shape[0],-1,-1) # expand for the batch size
        x=torch.cat((cls_tokens,x),dim=1)
        # Looking at the 16x16 paper Figure-1, pos_embedding are added to the concanated flatten image with cls_token
        x=x+self.pos_embedding
        x=self.dropout(x)
        x=self.transformer(x,mask)
        x=self.to_cls_token(x[:,0]) # get rid of 2nd dimension elements now only [batch,dim]
        x=self.fc1(x)
        
        return x

# %%
class Transformer(nn.Module):
    def __init__(self,dim,depth,heads,mlp_dim,dropout):
        super(Transformer,self).__init__()
        self.layers=nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                Residual(LayerNormalize(dim,Attention(dim,heads=heads,dropout=dropout))),
                Residual(LayerNormalize(dim,MLP_Block(dim,mlp_dim,dropout=dropout)))
            ]))
            
    def forward(self,x,mask=None):
        for attention,mlp in self.layers:
            x=attention(x,mask=mask)
            x=mlp(x)
        return x

# %%
class Attention(nn.Module):
    def __init__(self,dim, heads=8,dropout=0.1):
        super(Attention,self).__init__()
        self.heads=heads
        self.scale=dim** -0.5
        
        self.to_qvk=nn.Linear(dim,dim*3,bias=True)
        torch.nn.init.xavier_uniform_(self.to_qvk.weight)
        torch.nn.init.zeros_(self.to_qvk.bias)
        
        self.fc1=nn.Linear(dim,dim)
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.zeros_(self.fc1.bias)
        self.drop1=nn.Dropout(dropout)
        
    def forward(self,x,mask=None):
        b,n, _,h= *x.shape,self.heads
        qkv=self.to_qvk(x)
        q,k,v=einops.rearrange(qkv,'b n (qkv h d) -> qkv b h n d',qkv=3, h=h)
        
        dots=torch.einsum('bhid,bhjd->bhij',q,k) * self.scale
        
        attn=dots.softmax(dim=-1)
        
        out=torch.einsum('bhij,bhjd->bhid',attn,v)
        out=einops.rearrange(out,'b h n d -> b n (h d)')
        out=self.fc1(out)
        out=self.drop1(out)
        return out

# %%
class LayerNormalize(nn.Module):
    def __init__(self,dim,fn):
        super(LayerNormalize,self).__init__()
        self.norm=nn.LayerNorm(dim)
        self.fn=fn
        
    def forward(self,x,**kwargs):
        return self.fn(self.norm(x),**kwargs)

# %%
class Residual(nn.Module):
    def __init__(self,fn):
        super(Residual,self).__init__()
        self.fn=fn
        
    def forward(self,x,**kwargs):
        return self.fn(x,**kwargs) + x

# %%
class MLP_Block(nn.Module):
    def __init__(self,dim,hidden_dim,dropout=0.1):
        super(MLP_Block,self).__init__()
        self.fc1=nn.Linear(dim,hidden_dim)
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.normal_(self.fc1.bias,std= 1e-6)
        self.af1=nn.GELU()
        self.drop1=nn.Dropout(dropout)
        self.fc2=nn.Linear(hidden_dim,dim)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        torch.nn.init.normal_(self.fc2.bias,std=1e-6)
        self.drop2=nn.Dropout(dropout)
        
    def forward(self,x):
        x=self.fc1(x)
        x=self.af1(x)
        x=self.drop1(x)
        x=self.fc2(x)
        x=self.drop2(x)
        
        return x

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
transform_config=transforms.Compose(
     [torchvision.transforms.RandomHorizontalFlip(),
     torchvision.transforms.RandomAffine(8, translate=(.15,.15)),
     torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

# %%
train_dataset=datasets.CIFAR10('/home/ubuntu/gpu_work',download=True,train=True,transform=transform_config)
test_dataset=datasets.CIFAR10('/home/ubuntu/gpu_work',download=True,train=False,transform=transform_config)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
BATCH_SIZE=256
train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=BATCH_SIZE,shuffle=True)
test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=BATCH_SIZE,shuffle=False)

# %%
model=ImageTransformer(image_size=32,patch_size=4,num_classes=10,channels=3,dim=64,depth=6,
                      heads=4,mlp_dim=128).to(device)
optimizer=torch.optim.Adam(model.parameters(),lr=0.003)

# %%
def train(model,train_loader,optimizer,epoch,device):
    model.train()
    for batch_ids, (data,label) in enumerate(train_loader):
        label=label.type(torch.LongTensor)
        data,label=data.to(device),label.to(device)
        
        optimizer.zero_grad()
        model_output=F.log_softmax(model(data), dim=1)
        loss=F.nll_loss(model_output,label)
        loss.backward()
        optimizer.step()
        
        if (batch_ids +1) % 50 ==0:
                print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                epoch,batch_ids*len(data),len(train_loader.dataset),
                100.*batch_ids/len(train_loader),loss.item()))

# %%
def test(model,test_loader,device):
    model.eval()
    correct=0
    with torch.no_grad():
        for data, label in test_loader:
            data,label=data.to(device),label.to(device)
            y_hat=F.log_softmax(model(data), dim=1)
            _,y_pred=torch.max(y_hat,1)
            correct+=(y_pred==label).sum().item()
        print("\n Test Set: Average loss: xx , Accuracy:{}/{} ({:.0f}%)".format(
            correct,len(test_dataset),100.*correct/len(test_dataset)))
        print("="*50)

# %%
if __name__=='__main__':
    seed=42
    EPOCHS=150
    
    for epoch in range (1,EPOCHS+1):
        train(model,train_loader,optimizer,epoch,device)
        test(model,test_loader,device)
# Out:
# Train Epoch: 1 [12544/50000 (25%)]	Loss: 2.108672
# Train Epoch: 1 [25344/50000 (51%)]	Loss: 1.949374
# Train Epoch: 1 [38144/50000 (76%)]	Loss: 1.705283
#
#  Test Set: Average loss: xx , Accuracy:3575/10000 (36%)
# ==================================================
# Train Epoch: 2 [12544/50000 (25%)]	Loss: 1.724646
# Train Epoch: 2 [25344/50000 (51%)]	Loss: 1.660031
# Train Epoch: 2 [38144/50000 (76%)]	Loss: 1.576633
#
#  Test Set: Average loss: xx , Accuracy:4370/10000 (44%)
# ==================================================
# Train Epoch: 3 [12544/50000 (25%)]	Loss: 1.729877
# Train Epoch: 3 [25344/50000 (51%)]	Loss: 1.449940
# Train Epoch: 3 [38144/50000 (76%)]	Loss: 1.397055
#
#  Test Set: Average loss: xx , Accuracy:4792/10000 (48%)
# ==================================================
# Train Epoch: 4 [12544/50000 (25%)]	Loss: 1.522130
# Train Epoch: 4 [25344/50000 (51%)]	Loss: 1.353905
# Train Epoch: 4 [38144/50000 (76%)]	Loss: 1.402612
#
#  Test Set: Average loss: xx , Accuracy:4930/10000 (49%)
# ==================================================
# Train Epoch: 5 [12544/50000 (25%)]	Loss: 1.311490
# Train Epoch: 5 [25344/50000 (51%)]	Loss: 1.212254
# Train Epoch: 5 [38144/50000 (76%)]	Loss: 1.307119
#
#  Test Set: Average loss: xx , Accuracy:5415/10000 (54%)
# ==================================================
# Train Epoch: 6 [12544/50000 (25%)]	Loss: 1.251049
# Train Epoch: 6 [25344/50000 (51%)]	Loss: 1.239203
# Train Epoch: 6 [38144/50000 (76%)]	Loss: 1.263449
#
#  Test Set: Average loss: xx , Accuracy:5690/10000 (57%)
# ==================================================
# Train Epoch: 7 [12544/50000 (25%)]	Loss: 1.328550
# Train Epoch: 7 [25344/50000 (51%)]	Loss: 1.252250
# Train Epoch: 7 [38144/50000 (76%)]	Loss: 1.347894
#
#  Test Set: Average loss: xx , Accuracy:5743/10000 (57%)
# ==================================================
# Train Epoch: 8 [12544/50000 (25%)]	Loss: 1.210211
# Train Epoch: 8 [25344/50000 (51%)]	Loss: 1.126898
# Train Epoch: 8 [38144/50000 (76%)]	Loss: 1.111033
#
#  Test Set: Average loss: xx , Accuracy:5833/10000 (58%)
# ==================================================
# Train Epoch: 9 [12544/50000 (25%)]	Loss: 1.193111
# Train Epoch: 9 [25344/50000 (51%)]	Loss: 1.092966
# Train Epoch: 9 [38144/50000 (76%)]	Loss: 1.102743
#
#  Test Set: Average loss: xx , Accuracy:6052/10000 (61%)
# ==================================================
# Train Epoch: 10 [12544/50000 (25%)]	Loss: 1.083833
# Train Epoch: 10 [25344/50000 (51%)]	Loss: 1.195749
# Train Epoch: 10 [38144/50000 (76%)]	Loss: 1.038808
#
#  Test Set: Average loss: xx , Accuracy:6231/10000 (62%)
# ==================================================
# Train Epoch: 11 [12544/50000 (25%)]	Loss: 1.151067
# Train Epoch: 11 [25344/50000 (51%)]	Loss: 1.053915
# Train Epoch: 11 [38144/50000 (76%)]	Loss: 1.039170
#
#  Test Set: Average loss: xx , Accuracy:6202/10000 (62%)
# ==================================================
# Train Epoch: 12 [12544/50000 (25%)]	Loss: 0.972607
# Train Epoch: 12 [25344/50000 (51%)]	Loss: 0.921911
# Train Epoch: 12 [38144/50000 (76%)]	Loss: 1.005767
#
#  Test Set: Average loss: xx , Accuracy:6475/10000 (65%)
# ==================================================
# Train Epoch: 13 [12544/50000 (25%)]	Loss: 1.051748
# Train Epoch: 13 [25344/50000 (51%)]	Loss: 0.982577
# Train Epoch: 13 [38144/50000 (76%)]	Loss: 1.000739
#
#  Test Set: Average loss: xx , Accuracy:6343/10000 (63%)
# ==================================================
# Train Epoch: 14 [12544/50000 (25%)]	Loss: 0.954033
# Train Epoch: 14 [25344/50000 (51%)]	Loss: 1.042893
# Train Epoch: 14 [38144/50000 (76%)]	Loss: 0.956526
#
#  Test Set: Average loss: xx , Accuracy:6496/10000 (65%)
# ==================================================
# Train Epoch: 15 [12544/50000 (25%)]	Loss: 0.980612
# Train Epoch: 15 [25344/50000 (51%)]	Loss: 0.971132
# Train Epoch: 15 [38144/50000 (76%)]	Loss: 0.948362
#
#  Test Set: Average loss: xx , Accuracy:6573/10000 (66%)
# ==================================================
# Train Epoch: 16 [12544/50000 (25%)]	Loss: 1.038581
# Train Epoch: 16 [25344/50000 (51%)]	Loss: 0.979845
# Train Epoch: 16 [38144/50000 (76%)]	Loss: 1.132254
#
#  Test Set: Average loss: xx , Accuracy:6476/10000 (65%)
# ==================================================
# Train Epoch: 17 [12544/50000 (25%)]	Loss: 1.042774
# Train Epoch: 17 [25344/50000 (51%)]	Loss: 1.002482
# Train Epoch: 17 [38144/50000 (76%)]	Loss: 1.003724
#
#  Test Set: Average loss: xx , Accuracy:6692/10000 (67%)
# ==================================================
# Train Epoch: 18 [12544/50000 (25%)]	Loss: 1.058085
# Train Epoch: 18 [25344/50000 (51%)]	Loss: 0.950203
# Train Epoch: 18 [38144/50000 (76%)]	Loss: 0.995567
#
#  Test Set: Average loss: xx , Accuracy:6762/10000 (68%)
# ==================================================
# Train Epoch: 19 [12544/50000 (25%)]	Loss: 0.896169
# Train Epoch: 19 [25344/50000 (51%)]	Loss: 0.954738
# Train Epoch: 19 [38144/50000 (76%)]	Loss: 1.019174
#
#  Test Set: Average loss: xx , Accuracy:6702/10000 (67%)
# ==================================================
# Train Epoch: 20 [12544/50000 (25%)]	Loss: 0.970881
# Train Epoch: 20 [25344/50000 (51%)]	Loss: 1.010860
# Train Epoch: 20 [38144/50000 (76%)]	Loss: 0.859210
#
#  Test Set: Average loss: xx , Accuracy:6826/10000 (68%)
# ==================================================
# Train Epoch: 21 [12544/50000 (25%)]	Loss: 0.867151
# Train Epoch: 21 [25344/50000 (51%)]	Loss: 0.930564
# Train Epoch: 21 [38144/50000 (76%)]	Loss: 1.015133
#
#  Test Set: Average loss: xx , Accuracy:6898/10000 (69%)
# ==================================================
# Train Epoch: 22 [12544/50000 (25%)]	Loss: 0.972222
# Train Epoch: 22 [25344/50000 (51%)]	Loss: 0.909734
# Train Epoch: 22 [38144/50000 (76%)]	Loss: 0.802222
#
#  Test Set: Average loss: xx , Accuracy:6779/10000 (68%)
# ==================================================
# Train Epoch: 23 [12544/50000 (25%)]	Loss: 0.929055
# Train Epoch: 23 [25344/50000 (51%)]	Loss: 0.921381
# Train Epoch: 23 [38144/50000 (76%)]	Loss: 0.964573
#
#  Test Set: Average loss: xx , Accuracy:6845/10000 (68%)
# ==================================================
# Train Epoch: 24 [12544/50000 (25%)]	Loss: 0.765368
# Train Epoch: 24 [25344/50000 (51%)]	Loss: 0.695026
# Train Epoch: 24 [38144/50000 (76%)]	Loss: 0.878670
#
#  Test Set: Average loss: xx , Accuracy:7062/10000 (71%)
# ==================================================
# Train Epoch: 25 [12544/50000 (25%)]	Loss: 1.011899
# Train Epoch: 25 [25344/50000 (51%)]	Loss: 0.878819
# Train Epoch: 25 [38144/50000 (76%)]	Loss: 0.795819
#
#  Test Set: Average loss: xx , Accuracy:7104/10000 (71%)
# ==================================================
# Train Epoch: 26 [12544/50000 (25%)]	Loss: 0.941953
# Train Epoch: 26 [25344/50000 (51%)]	Loss: 0.846365
# Train Epoch: 26 [38144/50000 (76%)]	Loss: 0.848555
#
#  Test Set: Average loss: xx , Accuracy:7015/10000 (70%)
# ==================================================
# Train Epoch: 27 [12544/50000 (25%)]	Loss: 0.784357
# Train Epoch: 27 [25344/50000 (51%)]	Loss: 0.767783
# Train Epoch: 27 [38144/50000 (76%)]	Loss: 0.930706
#
#  Test Set: Average loss: xx , Accuracy:7050/10000 (70%)
# ==================================================
# Train Epoch: 28 [12544/50000 (25%)]	Loss: 0.764087
# Train Epoch: 28 [25344/50000 (51%)]	Loss: 0.788204
# Train Epoch: 28 [38144/50000 (76%)]	Loss: 0.826633
#
#  Test Set: Average loss: xx , Accuracy:7136/10000 (71%)
# ==================================================
# Train Epoch: 29 [12544/50000 (25%)]	Loss: 0.874241
# Train Epoch: 29 [25344/50000 (51%)]	Loss: 0.860261
# Train Epoch: 29 [38144/50000 (76%)]	Loss: 1.028131
#
#  Test Set: Average loss: xx , Accuracy:7116/10000 (71%)
# ==================================================
# Train Epoch: 30 [12544/50000 (25%)]	Loss: 0.692630
# Train Epoch: 30 [25344/50000 (51%)]	Loss: 0.800876
# Train Epoch: 30 [38144/50000 (76%)]	Loss: 0.708223
#
#  Test Set: Average loss: xx , Accuracy:7214/10000 (72%)
# ==================================================
# Train Epoch: 31 [12544/50000 (25%)]	Loss: 0.841333
# Train Epoch: 31 [25344/50000 (51%)]	Loss: 0.642407
# Train Epoch: 31 [38144/50000 (76%)]	Loss: 0.678560
#
#  Test Set: Average loss: xx , Accuracy:7245/10000 (72%)
# ==================================================
# Train Epoch: 32 [12544/50000 (25%)]	Loss: 0.808267
# Train Epoch: 32 [25344/50000 (51%)]	Loss: 0.725156
# Train Epoch: 32 [38144/50000 (76%)]	Loss: 0.866861
#  Test Set: Average loss: xx , Accuracy:7255/10000 (73%)
# ==================================================
# Train Epoch: 33 [12544/50000 (25%)]	Loss: 0.791775
# Train Epoch: 33 [25344/50000 (51%)]	Loss: 0.873868
# Train Epoch: 33 [38144/50000 (76%)]	Loss: 0.858541
#
#  Test Set: Average loss: xx , Accuracy:7166/10000 (72%)
# ==================================================
# Train Epoch: 34 [12544/50000 (25%)]	Loss: 0.781029
# Train Epoch: 34 [25344/50000 (51%)]	Loss: 0.863242
# Train Epoch: 34 [38144/50000 (76%)]	Loss: 0.771634
#
#  Test Set: Average loss: xx , Accuracy:7265/10000 (73%)
# ==================================================
# Train Epoch: 35 [12544/50000 (25%)]	Loss: 0.865978
# Train Epoch: 35 [25344/50000 (51%)]	Loss: 0.674622
# Train Epoch: 35 [38144/50000 (76%)]	Loss: 0.747496
#
#  Test Set: Average loss: xx , Accuracy:7237/10000 (72%)
# ==================================================
# Train Epoch: 36 [12544/50000 (25%)]	Loss: 0.794506
# Train Epoch: 36 [25344/50000 (51%)]	Loss: 0.836949
# Train Epoch: 36 [38144/50000 (76%)]	Loss: 0.754507
#
#  Test Set: Average loss: xx , Accuracy:7349/10000 (73%)
# ==================================================
# Train Epoch: 37 [12544/50000 (25%)]	Loss: 0.803337
# Train Epoch: 37 [25344/50000 (51%)]	Loss: 0.949883
# Train Epoch: 37 [38144/50000 (76%)]	Loss: 0.826165
#
#  Test Set: Average loss: xx , Accuracy:7299/10000 (73%)
# ==================================================
# Train Epoch: 38 [12544/50000 (25%)]	Loss: 0.792938
# Train Epoch: 38 [25344/50000 (51%)]	Loss: 0.661731
# Train Epoch: 38 [38144/50000 (76%)]	Loss: 0.857036
#
#  Test Set: Average loss: xx , Accuracy:7245/10000 (72%)
# ==================================================
# Train Epoch: 39 [12544/50000 (25%)]	Loss: 0.933546
# Train Epoch: 39 [25344/50000 (51%)]	Loss: 0.780509
# Train Epoch: 39 [38144/50000 (76%)]	Loss: 0.844553
#
#  Test Set: Average loss: xx , Accuracy:7291/10000 (73%)
# ==================================================
# Train Epoch: 40 [12544/50000 (25%)]	Loss: 0.797552
# Train Epoch: 40 [25344/50000 (51%)]	Loss: 0.721033
# Train Epoch: 40 [38144/50000 (76%)]	Loss: 0.692285
#
#  Test Set: Average loss: xx , Accuracy:7306/10000 (73%)
# ==================================================
# Train Epoch: 41 [12544/50000 (25%)]	Loss: 0.736849
# Train Epoch: 41 [25344/50000 (51%)]	Loss: 0.742332
# Train Epoch: 41 [38144/50000 (76%)]	Loss: 0.887140
#
#  Test Set: Average loss: xx , Accuracy:7372/10000 (74%)
# ==================================================
# Train Epoch: 42 [12544/50000 (25%)]	Loss: 0.829271
# Train Epoch: 42 [25344/50000 (51%)]	Loss: 0.767558
# Train Epoch: 42 [38144/50000 (76%)]	Loss: 0.835840
#
#  Test Set: Average loss: xx , Accuracy:7327/10000 (73%)
# ==================================================
# Train Epoch: 43 [12544/50000 (25%)]	Loss: 0.780794
# Train Epoch: 43 [25344/50000 (51%)]	Loss: 0.762753
# Train Epoch: 43 [38144/50000 (76%)]	Loss: 0.850321
#
#  Test Set: Average loss: xx , Accuracy:7293/10000 (73%)
# ==================================================
# Train Epoch: 44 [12544/50000 (25%)]	Loss: 0.770127
# Train Epoch: 44 [25344/50000 (51%)]	Loss: 0.815192
# Train Epoch: 44 [38144/50000 (76%)]	Loss: 0.745500
#
#  Test Set: Average loss: xx , Accuracy:7411/10000 (74%)
# ==================================================
# Train Epoch: 45 [12544/50000 (25%)]	Loss: 0.645671
# Train Epoch: 45 [25344/50000 (51%)]	Loss: 0.748680
# Train Epoch: 45 [38144/50000 (76%)]	Loss: 0.783351
#
#  Test Set: Average loss: xx , Accuracy:7312/10000 (73%)
# ==================================================
# Train Epoch: 46 [12544/50000 (25%)]	Loss: 0.685483
# Train Epoch: 46 [25344/50000 (51%)]	Loss: 0.653367
# Train Epoch: 46 [38144/50000 (76%)]	Loss: 0.754957
#
#  Test Set: Average loss: xx , Accuracy:7368/10000 (74%)
# ==================================================
# Train Epoch: 47 [12544/50000 (25%)]	Loss: 0.702425
# Train Epoch: 47 [25344/50000 (51%)]	Loss: 0.733831
# Train Epoch: 47 [38144/50000 (76%)]	Loss: 0.703589
#
#  Test Set: Average loss: xx , Accuracy:7487/10000 (75%)
# ==================================================
# Train Epoch: 48 [12544/50000 (25%)]	Loss: 0.697933
# Train Epoch: 48 [25344/50000 (51%)]	Loss: 0.801840
# Train Epoch: 48 [38144/50000 (76%)]	Loss: 0.672568
#
#  Test Set: Average loss: xx , Accuracy:7368/10000 (74%)
# ==================================================
# Train Epoch: 49 [12544/50000 (25%)]	Loss: 0.624257
# Train Epoch: 49 [25344/50000 (51%)]	Loss: 0.647798
# Train Epoch: 49 [38144/50000 (76%)]	Loss: 0.574332
#
#  Test Set: Average loss: xx , Accuracy:7323/10000 (73%)
# ==================================================
# Train Epoch: 50 [12544/50000 (25%)]	Loss: 0.726951
# Train Epoch: 50 [25344/50000 (51%)]	Loss: 0.644357
# Train Epoch: 50 [38144/50000 (76%)]	Loss: 0.765116
#
#  Test Set: Average loss: xx , Accuracy:7300/10000 (73%)
# ==================================================
# Train Epoch: 51 [12544/50000 (25%)]	Loss: 0.648003
# Train Epoch: 51 [25344/50000 (51%)]	Loss: 0.680442
# Train Epoch: 51 [38144/50000 (76%)]	Loss: 0.781432
#
#  Test Set: Average loss: xx , Accuracy:7412/10000 (74%)
# ==================================================
# Train Epoch: 52 [12544/50000 (25%)]	Loss: 0.634329
# Train Epoch: 52 [25344/50000 (51%)]	Loss: 0.758529
# Train Epoch: 52 [38144/50000 (76%)]	Loss: 0.660892
#
#  Test Set: Average loss: xx , Accuracy:7447/10000 (74%)
# ==================================================
# Train Epoch: 53 [12544/50000 (25%)]	Loss: 0.600373
# Train Epoch: 53 [25344/50000 (51%)]	Loss: 0.741009
# Train Epoch: 53 [38144/50000 (76%)]	Loss: 0.570996
#
#  Test Set: Average loss: xx , Accuracy:7577/10000 (76%)
# ==================================================
# Train Epoch: 54 [12544/50000 (25%)]	Loss: 0.616082
# Train Epoch: 54 [25344/50000 (51%)]	Loss: 0.760060
# Train Epoch: 54 [38144/50000 (76%)]	Loss: 0.809316
#
#  Test Set: Average loss: xx , Accuracy:7339/10000 (73%)
# ==================================================
# Train Epoch: 55 [12544/50000 (25%)]	Loss: 0.737981
# Train Epoch: 55 [25344/50000 (51%)]	Loss: 0.692825
# Train Epoch: 55 [38144/50000 (76%)]	Loss: 0.774194
#
#  Test Set: Average loss: xx , Accuracy:7523/10000 (75%)
# ==================================================
# Train Epoch: 56 [12544/50000 (25%)]	Loss: 0.708489
# Train Epoch: 56 [25344/50000 (51%)]	Loss: 0.640668
# Train Epoch: 56 [38144/50000 (76%)]	Loss: 0.629055
#
#  Test Set: Average loss: xx , Accuracy:7466/10000 (75%)
# ==================================================
# Train Epoch: 57 [12544/50000 (25%)]	Loss: 0.672249
# Train Epoch: 57 [25344/50000 (51%)]	Loss: 0.684324
# Train Epoch: 57 [38144/50000 (76%)]	Loss: 0.656424
#
#  Test Set: Average loss: xx , Accuracy:7547/10000 (75%)
# ==================================================
# Train Epoch: 58 [12544/50000 (25%)]	Loss: 0.650767
# Train Epoch: 58 [25344/50000 (51%)]	Loss: 0.794825
# Train Epoch: 58 [38144/50000 (76%)]	Loss: 0.625104
#
#  Test Set: Average loss: xx , Accuracy:7494/10000 (75%)
# ==================================================
# Train Epoch: 59 [12544/50000 (25%)]	Loss: 0.623623
# Train Epoch: 59 [25344/50000 (51%)]	Loss: 0.784023
# Train Epoch: 59 [38144/50000 (76%)]	Loss: 0.666138
#
#  Test Set: Average loss: xx , Accuracy:7490/10000 (75%)
# ==================================================
# Train Epoch: 60 [12544/50000 (25%)]	Loss: 0.585176
# Train Epoch: 60 [25344/50000 (51%)]	Loss: 0.533060
# Train Epoch: 60 [38144/50000 (76%)]	Loss: 0.668144
#
#  Test Set: Average loss: xx , Accuracy:7623/10000 (76%)
# ==================================================
# Train Epoch: 61 [12544/50000 (25%)]	Loss: 0.654917
# Train Epoch: 61 [25344/50000 (51%)]	Loss: 0.773195
# Train Epoch: 61 [38144/50000 (76%)]	Loss: 0.649898
#
#  Test Set: Average loss: xx , Accuracy:7616/10000 (76%)
# ==================================================
# Train Epoch: 62 [12544/50000 (25%)]	Loss: 0.548484
# Train Epoch: 62 [25344/50000 (51%)]	Loss: 0.691032
# Train Epoch: 62 [38144/50000 (76%)]	Loss: 0.764401
#
#  Test Set: Average loss: xx , Accuracy:7645/10000 (76%)
# ==================================================
# Train Epoch: 63 [12544/50000 (25%)]	Loss: 0.673627
# Train Epoch: 63 [25344/50000 (51%)]	Loss: 0.579128
# Train Epoch: 63 [38144/50000 (76%)]	Loss: 0.705182
#
#  Test Set: Average loss: xx , Accuracy:7581/10000 (76%)
# ==================================================
# Train Epoch: 64 [12544/50000 (25%)]	Loss: 0.694434
# Train Epoch: 64 [25344/50000 (51%)]	Loss: 0.679745
# Train Epoch: 64 [38144/50000 (76%)]	Loss: 0.623158
#
#  Test Set: Average loss: xx , Accuracy:7495/10000 (75%)
# ==================================================
# Train Epoch: 65 [12544/50000 (25%)]	Loss: 0.718816
# Train Epoch: 65 [25344/50000 (51%)]	Loss: 0.625653
# Train Epoch: 65 [38144/50000 (76%)]	Loss: 0.684870
#
#  Test Set: Average loss: xx , Accuracy:7588/10000 (76%)
# ==================================================
# Train Epoch: 66 [12544/50000 (25%)]	Loss: 0.655621
# Train Epoch: 66 [25344/50000 (51%)]	Loss: 0.611999
# Train Epoch: 66 [38144/50000 (76%)]	Loss: 0.696074
#
#  Test Set: Average loss: xx , Accuracy:7651/10000 (77%)
# ==================================================
# Train Epoch: 67 [12544/50000 (25%)]	Loss: 0.628885
# Train Epoch: 67 [25344/50000 (51%)]	Loss: 0.691909
# Train Epoch: 67 [38144/50000 (76%)]	Loss: 0.641207
#
#  Test Set: Average loss: xx , Accuracy:7579/10000 (76%)
# ==================================================
# Train Epoch: 68 [12544/50000 (25%)]	Loss: 0.621807
# Train Epoch: 68 [25344/50000 (51%)]	Loss: 0.640971
# Train Epoch: 68 [38144/50000 (76%)]	Loss: 0.621586
#
#  Test Set: Average loss: xx , Accuracy:7660/10000 (77%)
# ==================================================
# Train Epoch: 69 [12544/50000 (25%)]	Loss: 0.559013
# Train Epoch: 69 [25344/50000 (51%)]	Loss: 0.695556
# Train Epoch: 69 [38144/50000 (76%)]	Loss: 0.627738
#
#  Test Set: Average loss: xx , Accuracy:7638/10000 (76%)
# ==================================================
# Train Epoch: 70 [12544/50000 (25%)]	Loss: 0.597112
# Train Epoch: 70 [25344/50000 (51%)]	Loss: 0.718527
# Train Epoch: 70 [38144/50000 (76%)]	Loss: 0.562312
#
#  Test Set: Average loss: xx , Accuracy:7574/10000 (76%)
# ==================================================
# Train Epoch: 71 [12544/50000 (25%)]	Loss: 0.606445
# Train Epoch: 71 [25344/50000 (51%)]	Loss: 0.764060
# Train Epoch: 71 [38144/50000 (76%)]	Loss: 0.596291
#
#  Test Set: Average loss: xx , Accuracy:7597/10000 (76%)
# ==================================================
# Train Epoch: 72 [12544/50000 (25%)]	Loss: 0.673566
# Train Epoch: 72 [25344/50000 (51%)]	Loss: 0.591297
# Train Epoch: 72 [38144/50000 (76%)]	Loss: 0.799425
#
#  Test Set: Average loss: xx , Accuracy:7615/10000 (76%)
# ==================================================
# Train Epoch: 73 [12544/50000 (25%)]	Loss: 0.606819
# Train Epoch: 73 [25344/50000 (51%)]	Loss: 0.678429
# Train Epoch: 73 [38144/50000 (76%)]	Loss: 0.541725
#
#  Test Set: Average loss: xx , Accuracy:7654/10000 (77%)
# ==================================================
# Train Epoch: 74 [12544/50000 (25%)]	Loss: 0.531984
# Train Epoch: 74 [25344/50000 (51%)]	Loss: 0.593324
# Train Epoch: 74 [38144/50000 (76%)]	Loss: 0.664462
#
#  Test Set: Average loss: xx , Accuracy:7628/10000 (76%)
# ==================================================
# Train Epoch: 75 [12544/50000 (25%)]	Loss: 0.619159
# Train Epoch: 75 [25344/50000 (51%)]	Loss: 0.687633
# Train Epoch: 75 [38144/50000 (76%)]	Loss: 0.523822
#
#  Test Set: Average loss: xx , Accuracy:7720/10000 (77%)
# ==================================================
# Train Epoch: 76 [12544/50000 (25%)]	Loss: 0.717430
# Train Epoch: 76 [25344/50000 (51%)]	Loss: 0.525128
# Train Epoch: 76 [38144/50000 (76%)]	Loss: 0.639225
#
#  Test Set: Average loss: xx , Accuracy:7592/10000 (76%)
# ==================================================
# Train Epoch: 77 [12544/50000 (25%)]	Loss: 0.555811
# Train Epoch: 77 [25344/50000 (51%)]	Loss: 0.676365
# Train Epoch: 77 [38144/50000 (76%)]	Loss: 0.625253
#
#  Test Set: Average loss: xx , Accuracy:7581/10000 (76%)
# ==================================================
# Train Epoch: 78 [12544/50000 (25%)]	Loss: 0.578531
# Train Epoch: 78 [25344/50000 (51%)]	Loss: 0.673421
# Train Epoch: 78 [38144/50000 (76%)]	Loss: 0.661289
#
#  Test Set: Average loss: xx , Accuracy:7703/10000 (77%)
# ==================================================
# Train Epoch: 79 [12544/50000 (25%)]	Loss: 0.611711
# Train Epoch: 79 [25344/50000 (51%)]	Loss: 0.545507
# Train Epoch: 79 [38144/50000 (76%)]	Loss: 0.636276
#
#  Test Set: Average loss: xx , Accuracy:7675/10000 (77%)
# ==================================================
# Train Epoch: 80 [12544/50000 (25%)]	Loss: 0.586135
# Train Epoch: 80 [25344/50000 (51%)]	Loss: 0.617521
# Train Epoch: 80 [38144/50000 (76%)]	Loss: 0.649786
#
#  Test Set: Average loss: xx , Accuracy:7516/10000 (75%)
# ==================================================
# Train Epoch: 81 [12544/50000 (25%)]	Loss: 0.527324
# Train Epoch: 81 [25344/50000 (51%)]	Loss: 0.564361
# Train Epoch: 81 [38144/50000 (76%)]	Loss: 0.638081
#
#  Test Set: Average loss: xx , Accuracy:7624/10000 (76%)
# ==================================================
# Train Epoch: 82 [12544/50000 (25%)]	Loss: 0.522622
# Train Epoch: 82 [25344/50000 (51%)]	Loss: 0.510601
# Train Epoch: 82 [38144/50000 (76%)]	Loss: 0.573175
#
#  Test Set: Average loss: xx , Accuracy:7651/10000 (77%)
# ==================================================
# Train Epoch: 83 [12544/50000 (25%)]	Loss: 0.558976
# Train Epoch: 83 [25344/50000 (51%)]	Loss: 0.540706
# Train Epoch: 83 [38144/50000 (76%)]	Loss: 0.470874
#
#  Test Set: Average loss: xx , Accuracy:7721/10000 (77%)
# ==================================================
# Train Epoch: 84 [12544/50000 (25%)]	Loss: 0.580224
# Train Epoch: 84 [25344/50000 (51%)]	Loss: 0.637562
# Train Epoch: 84 [38144/50000 (76%)]	Loss: 0.710267
#
#  Test Set: Average loss: xx , Accuracy:7723/10000 (77%)
# ==================================================
# Train Epoch: 85 [12544/50000 (25%)]	Loss: 0.605823
# Train Epoch: 85 [25344/50000 (51%)]	Loss: 0.552840
# Train Epoch: 85 [38144/50000 (76%)]	Loss: 0.644729
#
#  Test Set: Average loss: xx , Accuracy:7681/10000 (77%)
# ==================================================
# Train Epoch: 86 [12544/50000 (25%)]	Loss: 0.527097
# Train Epoch: 86 [25344/50000 (51%)]	Loss: 0.624322
# Train Epoch: 86 [38144/50000 (76%)]	Loss: 0.566889
#
#  Test Set: Average loss: xx , Accuracy:7722/10000 (77%)
# ==================================================
# Train Epoch: 87 [12544/50000 (25%)]	Loss: 0.576633
# Train Epoch: 87 [25344/50000 (51%)]	Loss: 0.613817
# Train Epoch: 87 [38144/50000 (76%)]	Loss: 0.577396
#
#  Test Set: Average loss: xx , Accuracy:7694/10000 (77%)
# ==================================================
# Train Epoch: 88 [12544/50000 (25%)]	Loss: 0.570344
# Train Epoch: 88 [25344/50000 (51%)]	Loss: 0.618018
# Train Epoch: 88 [38144/50000 (76%)]	Loss: 0.498305
#
#  Test Set: Average loss: xx , Accuracy:7696/10000 (77%)
# ==================================================
# Train Epoch: 89 [12544/50000 (25%)]	Loss: 0.618358
# Train Epoch: 89 [25344/50000 (51%)]	Loss: 0.669624
# Train Epoch: 89 [38144/50000 (76%)]	Loss: 0.611034
#
#  Test Set: Average loss: xx , Accuracy:7741/10000 (77%)
# ==================================================
# Train Epoch: 90 [12544/50000 (25%)]	Loss: 0.656220
# Train Epoch: 90 [25344/50000 (51%)]	Loss: 0.457376
# Train Epoch: 90 [38144/50000 (76%)]	Loss: 0.611753
#
#  Test Set: Average loss: xx , Accuracy:7706/10000 (77%)
# ==================================================
# Train Epoch: 91 [12544/50000 (25%)]	Loss: 0.640385
# Train Epoch: 91 [25344/50000 (51%)]	Loss: 0.607239
# Train Epoch: 91 [38144/50000 (76%)]	Loss: 0.678316
#
#  Test Set: Average loss: xx , Accuracy:7691/10000 (77%)
# ==================================================
# Train Epoch: 92 [12544/50000 (25%)]	Loss: 0.520980
# Train Epoch: 92 [25344/50000 (51%)]	Loss: 0.574079
# Train Epoch: 92 [38144/50000 (76%)]	Loss: 0.515414
#
#  Test Set: Average loss: xx , Accuracy:7648/10000 (76%)
# ==================================================
# Train Epoch: 93 [12544/50000 (25%)]	Loss: 0.618963
# Train Epoch: 93 [25344/50000 (51%)]	Loss: 0.546545
# Train Epoch: 93 [38144/50000 (76%)]	Loss: 0.597499
#
#  Test Set: Average loss: xx , Accuracy:7724/10000 (77%)
# ==================================================
# Train Epoch: 94 [12544/50000 (25%)]	Loss: 0.522212
# Train Epoch: 94 [25344/50000 (51%)]	Loss: 0.619182
# Train Epoch: 94 [38144/50000 (76%)]	Loss: 0.538960
#
#  Test Set: Average loss: xx , Accuracy:7781/10000 (78%)
# ==================================================
# Train Epoch: 95 [12544/50000 (25%)]	Loss: 0.552043
# Train Epoch: 95 [25344/50000 (51%)]	Loss: 0.629354
# Train Epoch: 95 [38144/50000 (76%)]	Loss: 0.629677
#
#  Test Set: Average loss: xx , Accuracy:7573/10000 (76%)
# ==================================================
# Train Epoch: 96 [12544/50000 (25%)]	Loss: 0.599802
# Train Epoch: 96 [25344/50000 (51%)]	Loss: 0.655138
# Train Epoch: 96 [38144/50000 (76%)]	Loss: 0.541623
#
#  Test Set: Average loss: xx , Accuracy:7697/10000 (77%)
# ==================================================
# Train Epoch: 97 [12544/50000 (25%)]	Loss: 0.586406
# Train Epoch: 97 [25344/50000 (51%)]	Loss: 0.620715
# Train Epoch: 97 [38144/50000 (76%)]	Loss: 0.763425
#
#  Test Set: Average loss: xx , Accuracy:7710/10000 (77%)
# ==================================================
# Train Epoch: 98 [12544/50000 (25%)]	Loss: 0.568846
# Train Epoch: 98 [25344/50000 (51%)]	Loss: 0.595475
# Train Epoch: 98 [38144/50000 (76%)]	Loss: 0.610067
#
#  Test Set: Average loss: xx , Accuracy:7744/10000 (77%)
# ==================================================
# Train Epoch: 99 [12544/50000 (25%)]	Loss: 0.678268
# Train Epoch: 99 [25344/50000 (51%)]	Loss: 0.685098
# Train Epoch: 99 [38144/50000 (76%)]	Loss: 0.554853
#
#  Test Set: Average loss: xx , Accuracy:7729/10000 (77%)
# ==================================================
# Train Epoch: 100 [12544/50000 (25%)]	Loss: 0.565977
# Train Epoch: 100 [25344/50000 (51%)]	Loss: 0.618686
# Train Epoch: 100 [38144/50000 (76%)]	Loss: 0.517308
#
#  Test Set: Average loss: xx , Accuracy:7636/10000 (76%)
# ==================================================
# Train Epoch: 101 [12544/50000 (25%)]	Loss: 0.556569
# Train Epoch: 101 [25344/50000 (51%)]	Loss: 0.560226
# Train Epoch: 101 [38144/50000 (76%)]	Loss: 0.591001
#
#  Test Set: Average loss: xx , Accuracy:7676/10000 (77%)
# ==================================================
# Train Epoch: 102 [12544/50000 (25%)]	Loss: 0.518409
# Train Epoch: 102 [25344/50000 (51%)]	Loss: 0.569354
# Train Epoch: 102 [38144/50000 (76%)]	Loss: 0.634966
#
#  Test Set: Average loss: xx , Accuracy:7781/10000 (78%)
# ==================================================
# Train Epoch: 103 [12544/50000 (25%)]	Loss: 0.501094
# Train Epoch: 103 [25344/50000 (51%)]	Loss: 0.532739
# Train Epoch: 103 [38144/50000 (76%)]	Loss: 0.533784
#
#  Test Set: Average loss: xx , Accuracy:7781/10000 (78%)
# ==================================================
# Train Epoch: 104 [12544/50000 (25%)]	Loss: 0.572209
# Train Epoch: 104 [25344/50000 (51%)]	Loss: 0.522182
# Train Epoch: 104 [38144/50000 (76%)]	Loss: 0.585384
#
#  Test Set: Average loss: xx , Accuracy:7782/10000 (78%)
# ==================================================
# Train Epoch: 105 [12544/50000 (25%)]	Loss: 0.588097
# Train Epoch: 105 [25344/50000 (51%)]	Loss: 0.667435
# Train Epoch: 105 [38144/50000 (76%)]	Loss: 0.567484
#
#  Test Set: Average loss: xx , Accuracy:7795/10000 (78%)
# ==================================================
# Train Epoch: 106 [12544/50000 (25%)]	Loss: 0.399408
# Train Epoch: 106 [25344/50000 (51%)]	Loss: 0.496505
# Train Epoch: 106 [38144/50000 (76%)]	Loss: 0.578294
#
#  Test Set: Average loss: xx , Accuracy:7713/10000 (77%)
# ==================================================
# Train Epoch: 107 [12544/50000 (25%)]	Loss: 0.494090
# Train Epoch: 107 [25344/50000 (51%)]	Loss: 0.564393
# Train Epoch: 107 [38144/50000 (76%)]	Loss: 0.666880
#
#  Test Set: Average loss: xx , Accuracy:7676/10000 (77%)
# ==================================================
# Train Epoch: 108 [12544/50000 (25%)]	Loss: 0.729762
# Train Epoch: 108 [25344/50000 (51%)]	Loss: 0.624036
# Train Epoch: 108 [38144/50000 (76%)]	Loss: 0.616688
#
#  Test Set: Average loss: xx , Accuracy:7669/10000 (77%)
# ==================================================
# Train Epoch: 109 [12544/50000 (25%)]	Loss: 0.581426
# Train Epoch: 109 [25344/50000 (51%)]	Loss: 0.456308
# Train Epoch: 109 [38144/50000 (76%)]	Loss: 0.552189
#
#  Test Set: Average loss: xx , Accuracy:7710/10000 (77%)
# ==================================================
# Train Epoch: 110 [12544/50000 (25%)]	Loss: 0.580715
# Train Epoch: 110 [25344/50000 (51%)]	Loss: 0.516548
# Train Epoch: 110 [38144/50000 (76%)]	Loss: 0.617346
#
#  Test Set: Average loss: xx , Accuracy:7646/10000 (76%)
# ==================================================
# Train Epoch: 111 [12544/50000 (25%)]	Loss: 0.525766
# Train Epoch: 111 [25344/50000 (51%)]	Loss: 0.541013
# Train Epoch: 111 [38144/50000 (76%)]	Loss: 0.626239
#
#  Test Set: Average loss: xx , Accuracy:7629/10000 (76%)
# ==================================================
# Train Epoch: 112 [12544/50000 (25%)]	Loss: 0.576601
# Train Epoch: 112 [25344/50000 (51%)]	Loss: 0.465564
# Train Epoch: 112 [38144/50000 (76%)]	Loss: 0.613508
#
#  Test Set: Average loss: xx , Accuracy:7741/10000 (77%)
# ==================================================
# Train Epoch: 113 [12544/50000 (25%)]	Loss: 0.625928
# Train Epoch: 113 [25344/50000 (51%)]	Loss: 0.554236
# Train Epoch: 113 [38144/50000 (76%)]	Loss: 0.494583
#
#  Test Set: Average loss: xx , Accuracy:7688/10000 (77%)
# ==================================================
# Train Epoch: 114 [12544/50000 (25%)]	Loss: 0.515982
# Train Epoch: 114 [25344/50000 (51%)]	Loss: 0.497959
# Train Epoch: 114 [38144/50000 (76%)]	Loss: 0.469087
#
#  Test Set: Average loss: xx , Accuracy:7670/10000 (77%)
# ==================================================
# Train Epoch: 115 [12544/50000 (25%)]	Loss: 0.523471
# Train Epoch: 115 [25344/50000 (51%)]	Loss: 0.474007
# Train Epoch: 115 [38144/50000 (76%)]	Loss: 0.738500
#
#  Test Set: Average loss: xx , Accuracy:7762/10000 (78%)
# ==================================================
# Train Epoch: 116 [12544/50000 (25%)]	Loss: 0.569607
# Train Epoch: 116 [25344/50000 (51%)]	Loss: 0.531367
# Train Epoch: 116 [38144/50000 (76%)]	Loss: 0.597553
#
#  Test Set: Average loss: xx , Accuracy:7807/10000 (78%)
# ==================================================
# Train Epoch: 117 [12544/50000 (25%)]	Loss: 0.561727
# Train Epoch: 117 [25344/50000 (51%)]	Loss: 0.542868
# Train Epoch: 117 [38144/50000 (76%)]	Loss: 0.664292
#
#  Test Set: Average loss: xx , Accuracy:7752/10000 (78%)
# ==================================================
# Train Epoch: 118 [12544/50000 (25%)]	Loss: 0.638337
# Train Epoch: 118 [25344/50000 (51%)]	Loss: 0.576829
# Train Epoch: 118 [38144/50000 (76%)]	Loss: 0.575953
#
#  Test Set: Average loss: xx , Accuracy:7732/10000 (77%)
# ==================================================
# Train Epoch: 119 [12544/50000 (25%)]	Loss: 0.493403
# Train Epoch: 119 [25344/50000 (51%)]	Loss: 0.543586
# Train Epoch: 119 [38144/50000 (76%)]	Loss: 0.573847
#
#  Test Set: Average loss: xx , Accuracy:7796/10000 (78%)
# ==================================================
# Train Epoch: 120 [12544/50000 (25%)]	Loss: 0.605997
# Train Epoch: 120 [25344/50000 (51%)]	Loss: 0.580020
# Train Epoch: 120 [38144/50000 (76%)]	Loss: 0.594575
#
#  Test Set: Average loss: xx , Accuracy:7726/10000 (77%)
# ==================================================
# Train Epoch: 121 [12544/50000 (25%)]	Loss: 0.570455
# Train Epoch: 121 [25344/50000 (51%)]	Loss: 0.483329
# Train Epoch: 121 [38144/50000 (76%)]	Loss: 0.544564
#
#  Test Set: Average loss: xx , Accuracy:7781/10000 (78%)
# ==================================================
# Train Epoch: 122 [12544/50000 (25%)]	Loss: 0.567854
# Train Epoch: 122 [25344/50000 (51%)]	Loss: 0.478182
# Train Epoch: 122 [38144/50000 (76%)]	Loss: 0.586725
#
#  Test Set: Average loss: xx , Accuracy:7817/10000 (78%)
# ==================================================
# Train Epoch: 123 [12544/50000 (25%)]	Loss: 0.577042
# Train Epoch: 123 [25344/50000 (51%)]	Loss: 0.540061
# Train Epoch: 123 [38144/50000 (76%)]	Loss: 0.603162
#
#  Test Set: Average loss: xx , Accuracy:7727/10000 (77%)
# ==================================================
# Train Epoch: 124 [12544/50000 (25%)]	Loss: 0.486952
# Train Epoch: 124 [25344/50000 (51%)]	Loss: 0.577095
# Train Epoch: 124 [38144/50000 (76%)]	Loss: 0.463939
#
#  Test Set: Average loss: xx , Accuracy:7688/10000 (77%)
# ==================================================
# Train Epoch: 125 [12544/50000 (25%)]	Loss: 0.564952
# Train Epoch: 125 [25344/50000 (51%)]	Loss: 0.530312
# Train Epoch: 125 [38144/50000 (76%)]	Loss: 0.677273
#
#  Test Set: Average loss: xx , Accuracy:7741/10000 (77%)
# ==================================================
# Train Epoch: 126 [12544/50000 (25%)]	Loss: 0.439376
# Train Epoch: 126 [25344/50000 (51%)]	Loss: 0.493814
# Train Epoch: 126 [38144/50000 (76%)]	Loss: 0.593101
#  Test Set: Average loss: xx , Accuracy:7821/10000 (78%)
# ==================================================
# Train Epoch: 127 [12544/50000 (25%)]	Loss: 0.531117
# Train Epoch: 127 [25344/50000 (51%)]	Loss: 0.585207
# Train Epoch: 127 [38144/50000 (76%)]	Loss: 0.556033
#
#  Test Set: Average loss: xx , Accuracy:7812/10000 (78%)
# ==================================================
# Train Epoch: 128 [12544/50000 (25%)]	Loss: 0.501893
# Train Epoch: 128 [25344/50000 (51%)]	Loss: 0.507147
# Train Epoch: 128 [38144/50000 (76%)]	Loss: 0.491432
#
#  Test Set: Average loss: xx , Accuracy:7748/10000 (77%)
# ==================================================
# Train Epoch: 129 [12544/50000 (25%)]	Loss: 0.578929
# Train Epoch: 129 [25344/50000 (51%)]	Loss: 0.563884
# Train Epoch: 129 [38144/50000 (76%)]	Loss: 0.452889
#
#  Test Set: Average loss: xx , Accuracy:7734/10000 (77%)
# ==================================================
# Train Epoch: 130 [12544/50000 (25%)]	Loss: 0.523191
# Train Epoch: 130 [25344/50000 (51%)]	Loss: 0.616155
# Train Epoch: 130 [38144/50000 (76%)]	Loss: 0.528766
#
#  Test Set: Average loss: xx , Accuracy:7745/10000 (77%)
# ==================================================
# Train Epoch: 131 [12544/50000 (25%)]	Loss: 0.462200
# Train Epoch: 131 [25344/50000 (51%)]	Loss: 0.515960
# Train Epoch: 131 [38144/50000 (76%)]	Loss: 0.510168
#
#  Test Set: Average loss: xx , Accuracy:7774/10000 (78%)
# ==================================================
# Train Epoch: 132 [12544/50000 (25%)]	Loss: 0.630443
# Train Epoch: 132 [25344/50000 (51%)]	Loss: 0.525234
# Train Epoch: 132 [38144/50000 (76%)]	Loss: 0.554866
#
#  Test Set: Average loss: xx , Accuracy:7797/10000 (78%)
# ==================================================
# Train Epoch: 133 [12544/50000 (25%)]	Loss: 0.481194
# Train Epoch: 133 [25344/50000 (51%)]	Loss: 0.613948
# Train Epoch: 133 [38144/50000 (76%)]	Loss: 0.629039
#
#  Test Set: Average loss: xx , Accuracy:7733/10000 (77%)
# ==================================================
# Train Epoch: 134 [12544/50000 (25%)]	Loss: 0.493196
# Train Epoch: 134 [25344/50000 (51%)]	Loss: 0.530448
# Train Epoch: 134 [38144/50000 (76%)]	Loss: 0.549492
#
#  Test Set: Average loss: xx , Accuracy:7731/10000 (77%)
# ==================================================
# Train Epoch: 135 [12544/50000 (25%)]	Loss: 0.537967
# Train Epoch: 135 [25344/50000 (51%)]	Loss: 0.578172
# Train Epoch: 135 [38144/50000 (76%)]	Loss: 0.483745
#
#  Test Set: Average loss: xx , Accuracy:7865/10000 (79%)
# ==================================================
# Train Epoch: 136 [12544/50000 (25%)]	Loss: 0.533125
# Train Epoch: 136 [25344/50000 (51%)]	Loss: 0.551140
# Train Epoch: 136 [38144/50000 (76%)]	Loss: 0.511326
#
#  Test Set: Average loss: xx , Accuracy:7756/10000 (78%)
# ==================================================
# Train Epoch: 137 [12544/50000 (25%)]	Loss: 0.481238
# Train Epoch: 137 [25344/50000 (51%)]	Loss: 0.516618
# Train Epoch: 137 [38144/50000 (76%)]	Loss: 0.521787
#
#  Test Set: Average loss: xx , Accuracy:7762/10000 (78%)
# ==================================================
# Train Epoch: 138 [12544/50000 (25%)]	Loss: 0.481233
# Train Epoch: 138 [25344/50000 (51%)]	Loss: 0.508094
# Train Epoch: 138 [38144/50000 (76%)]	Loss: 0.577279
#
#  Test Set: Average loss: xx , Accuracy:7729/10000 (77%)
# ==================================================
# Train Epoch: 139 [12544/50000 (25%)]	Loss: 0.543633
# Train Epoch: 139 [25344/50000 (51%)]	Loss: 0.588972
# Train Epoch: 139 [38144/50000 (76%)]	Loss: 0.458961
#
#  Test Set: Average loss: xx , Accuracy:7745/10000 (77%)
# ==================================================
# Train Epoch: 140 [12544/50000 (25%)]	Loss: 0.549788
# Train Epoch: 140 [25344/50000 (51%)]	Loss: 0.520197
# Train Epoch: 140 [38144/50000 (76%)]	Loss: 0.521030
#
#  Test Set: Average loss: xx , Accuracy:7788/10000 (78%)
# ==================================================
# Train Epoch: 141 [12544/50000 (25%)]	Loss: 0.538837
# Train Epoch: 141 [25344/50000 (51%)]	Loss: 0.568598
# Train Epoch: 141 [38144/50000 (76%)]	Loss: 0.482622
#
#  Test Set: Average loss: xx , Accuracy:7685/10000 (77%)
# ==================================================
# Train Epoch: 142 [12544/50000 (25%)]	Loss: 0.445801
# Train Epoch: 142 [25344/50000 (51%)]	Loss: 0.456599
# Train Epoch: 142 [38144/50000 (76%)]	Loss: 0.511480
#
#  Test Set: Average loss: xx , Accuracy:7688/10000 (77%)
# ==================================================
# Train Epoch: 143 [12544/50000 (25%)]	Loss: 0.469261
# Train Epoch: 143 [25344/50000 (51%)]	Loss: 0.470901
# Train Epoch: 143 [38144/50000 (76%)]	Loss: 0.494488
#
#  Test Set: Average loss: xx , Accuracy:7817/10000 (78%)
# ==================================================
# Train Epoch: 144 [12544/50000 (25%)]	Loss: 0.574130
# Train Epoch: 144 [25344/50000 (51%)]	Loss: 0.550256
# Train Epoch: 144 [38144/50000 (76%)]	Loss: 0.531174
#
#  Test Set: Average loss: xx , Accuracy:7813/10000 (78%)
# ==================================================
# Train Epoch: 145 [12544/50000 (25%)]	Loss: 0.525007
# Train Epoch: 145 [25344/50000 (51%)]	Loss: 0.539862
# Train Epoch: 145 [38144/50000 (76%)]	Loss: 0.492085
#
#  Test Set: Average loss: xx , Accuracy:7823/10000 (78%)
# ==================================================
# Train Epoch: 146 [12544/50000 (25%)]	Loss: 0.604532
# Train Epoch: 146 [25344/50000 (51%)]	Loss: 0.609426
# Train Epoch: 146 [38144/50000 (76%)]	Loss: 0.473985
#
#  Test Set: Average loss: xx , Accuracy:7774/10000 (78%)
# ==================================================
# Train Epoch: 147 [12544/50000 (25%)]	Loss: 0.641596
# Train Epoch: 147 [25344/50000 (51%)]	Loss: 0.431201
# Train Epoch: 147 [38144/50000 (76%)]	Loss: 0.442068
#
#  Test Set: Average loss: xx , Accuracy:7780/10000 (78%)
# ==================================================
# Train Epoch: 148 [12544/50000 (25%)]	Loss: 0.650295
# Train Epoch: 148 [25344/50000 (51%)]	Loss: 0.608082
# Train Epoch: 148 [38144/50000 (76%)]	Loss: 0.576077
#
#  Test Set: Average loss: xx , Accuracy:7797/10000 (78%)
# ==================================================
# Train Epoch: 149 [12544/50000 (25%)]	Loss: 0.464100
# Train Epoch: 149 [25344/50000 (51%)]	Loss: 0.475398
# Train Epoch: 149 [38144/50000 (76%)]	Loss: 0.489059
#
#  Test Set: Average loss: xx , Accuracy:7782/10000 (78%)
# ==================================================
# Train Epoch: 150 [12544/50000 (25%)]	Loss: 0.531994
# Train Epoch: 150 [25344/50000 (51%)]	Loss: 0.625588
# Train Epoch: 150 [38144/50000 (76%)]	Loss: 0.552419
#
#  Test Set: Average loss: xx , Accuracy:7804/10000 (78%)
# ==================================================
